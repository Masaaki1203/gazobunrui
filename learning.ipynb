# %% [markdown]
# <a href="https://colab.research.google.com/github/Masaaki1203/gazobunrui/blob/master/learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.path.append("/content/drive/My Drive/gazobunrui_lecture/my_modules")

# %%
import ic_module as ic

# 関数実行
ic.Learning(tsnum=30, nb_epoch=50, batch_size=8, learn_schedule=0.9)
# Out:
# >> 学習サンプル数 :  (116, 32, 32, 3)
# >> 学習開始
# Epoch 1/50
# 3/4 [=====================>........] - ETA: 0s - loss: 1.0374 - accuracy: 0.3750
# Epoch 00001: val_loss improved from inf to 1.78441, saving model to best.hdf5
# 4/4 [==============================] - 1s 141ms/step - loss: 0.9884 - accuracy: 0.4231 - val_loss: 1.7844 - val_accuracy: 0.3333
# Epoch 2/50
# 3/4 [=====================>........] - ETA: 0s - loss: 1.0892 - accuracy: 0.7083
# Epoch 00002: val_loss improved from 1.78441 to 1.40429, saving model to best.hdf5
# 4/4 [==============================] - 0s 80ms/step - loss: 1.0871 - accuracy: 0.6923 - val_loss: 1.4043 - val_accuracy: 0.3333
# Epoch 3/50
# 3/4 [=====================>........] - ETA: 0s - loss: 0.9037 - accuracy: 0.6667
# Epoch 00003: val_loss improved from 1.40429 to 1.18260, saving model to best.hdf5
# 4/4 [==============================] - 0s 86ms/step - loss: 0.8788 - accuracy: 0.6923 - val_loss: 1.1826 - val_accuracy: 0.3333
# Epoch 4/50
# ...
