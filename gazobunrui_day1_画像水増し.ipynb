# %% [markdown]
# <a href="https://colab.research.google.com/github/Masaaki1203/gazobunrui/blob/master/gazobunrui_day1_%E7%94%BB%E5%83%8F%E6%B0%B4%E5%A2%97%E3%81%97.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **取得した画像を水増し**
# 顔を自動で認識し，左右反転，ぼかしなどの処理を加える

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.image as mpimg
import sys
from keras.preprocessing.image import array_to_img,img_to_array,load_img
import numpy as np
import os


X_train=[]
Y_train=[]

X_test=[]
Y_test=[]

Mydribe = "/content/drive/My Drive/gazobunrui_lecture"

l=os.listdir(Mydribe + "/original_data")
l
# Out:
# ['.ipynb_checkpoints',
#  'TeruyukiKagawa',
#  'AinosukeKataoka',
#  'EnnosukeIchikawa',
#  'test']

# %%
# https://github.com/opencv/opencv/tree/master/data/haarcascades
# https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_alt.xml
cascade_path="/content/drive/My Drive/gazobunrui_lecture/haarcascade_frontalface_alt.xml"

for i in l:
    result_dir=i.split(".")[0]
    print(result_dir)
    # os.mkdir(Mydribe + "/face/"+result_dir)
    os.makedirs(Mydribe + "/face/"+result_dir, exist_ok=True)

    m=os.listdir(Mydribe + "/original_data/"+i)
    n=0
    for target_file in m:
        origin_image=(Mydribe + "/original_data/"+i+"/"+target_file)
        print(origin_image)
        cascade=cv2.CascadeClassifier(cascade_path)
        image=cv2.imread(origin_image)

        image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
        gray=cv2.cvtColor(image,cv2.COLOR_RGB2GRAY)
        plt.imshow(gray)

        facerect=cascade.detectMultiScale(gray,scaleFactor=1.1,minNeighbors=1,minSize=(10,10))

        for x,y,w,h in facerect:
            face=gray[y:y+h,x:x+w]
            face=cv2.resize(face,(128,128))
            save_path=Mydribe + "/face/"+result_dir+"/image_"+str(n)+".jpg"
            cv2.imwrite(save_path,face)
            n=n+1
            face=cv2.flip(face,1)
            save_path=Mydribe + "/face/"+result_dir+"/image_"+str(n)+".jpg"
            cv2.imwrite(save_path,face)
            n=n+1
            face=cv2.blur(face,(10,10))
            save_path=Mydribe + "/face/"+result_dir+"/image_"+str(n)+".jpg"
            cv2.imwrite(save_path,face)
            n=n+1
            face=cv2.blur(cv2.flip(face,1),(10,10))
            save_path=Mydribe + "/face/"+result_dir+"/image_"+str(n)+".jpg"
            cv2.imwrite(save_path,face)
            n=n+1
# Out:
# TeruyukiKagawa
# /content/drive/My Drive/gazobunrui_lecture/original_data/TeruyukiKagawa/000002.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/TeruyukiKagawa/000003.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/TeruyukiKagawa/000005.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/TeruyukiKagawa/000006.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/TeruyukiKagawa/000007.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/TeruyukiKagawa/000008.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/TeruyukiKagawa/000009.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/TeruyukiKagawa/000011.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/TeruyukiKagawa/000012.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/TeruyukiKagawa/000013.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/TeruyukiKagawa/000015.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/TeruyukiKagawa/000017.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/TeruyukiKagawa/000018.jpg
# AinosukeKataoka
# /content/drive/My Drive/gazobunrui_lecture/original_data/AinosukeKataoka/00021.jpeg
# /content/drive/My Drive/gazobunrui_lecture/original_data/AinosukeKataoka/000011.jpeg
# /content/drive/My Drive/gazobunrui_lecture/original_data/AinosukeKataoka/00020.jpeg
# /content/drive/My Drive/gazobunrui_lecture/original_data/AinosukeKataoka/04.jpeg
# /content/drive/My Drive/gazobunrui_lecture/original_data/AinosukeKataoka/01.jpeg
# /content/drive/My Drive/gazobunrui_lecture/original_data/AinosukeKataoka/02.jpeg
# /content/drive/My Drive/gazobunrui_lecture/original_data/AinosukeKataoka/03.jpeg
# /content/drive/My Drive/gazobunrui_lecture/original_data/AinosukeKataoka/10.jpeg
# /content/drive/My Drive/gazobunrui_lecture/original_data/AinosukeKataoka/09.jpeg
# EnnosukeIchikawa
# /content/drive/My Drive/gazobunrui_lecture/original_data/EnnosukeIchikawa/000003.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/EnnosukeIchikawa/000004.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/EnnosukeIchikawa/000005.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/EnnosukeIchikawa/000006.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/EnnosukeIchikawa/000008.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/EnnosukeIchikawa/000016.jpg
# test
# /content/drive/My Drive/gazobunrui_lecture/original_data/test/000012.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/test/000018.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/test/000009.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/test/000011.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/test/000001.jpg
# /content/drive/My Drive/gazobunrui_lecture/original_data/test/000004.jpg
